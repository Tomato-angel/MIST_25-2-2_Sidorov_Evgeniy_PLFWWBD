# %% [markdown]
# # Развёртывание

# %% [markdown]
# Установка была проведена для **Windows 10** с использованием **wsl**. Полная инструкция по клоинрованию данного репозитория и всеми быстрыми командами, так же как и его полное описание представлены в главном **README.md**

# %% [markdown]
# ## Часть 1. Установка

# %% [markdown]
# ### Описание выполнения заданий

# %% [markdown]
# - Выбрать один из трех путей установки: <font color="blue">**WSL**</font>;
# - Установить все по инструкции из этой тетрадки или рекомендациям чатГПТ: <font color="blue"> Устанавливал по инструкции, всё получилось, однако, позволю себе заметить, в ней не хватает пункта перехода в каталог пользователя <font color="green"> **cd ~** </font>, иначе все основные файлы по умолчанию создаются на диске **C:\\** в документах</font>;
# - Запустить Jupyter Lab/Notebook: <font color="blue">В вирутальном окружении **.venv** всё успешно создано, сам каталог виртуального окружения исключён в .gitignore</font>;
# - Создать новую тетрадку с именем homework_01.ipynb: <font color="blue">Успешно сделано</font>
# - В первой ячейке написать код: print("Меня зовут [Ваше Имя], и я готов(а) страдать на курсе!"): <font color="blue">Результат предствлен ниже.</font>
# - Сделать скриншот результата (чтобы было видно и код, и результат) и прислать в наш телеграм-чат: <font color="red">Данный результат не представлен, в качестве альтернативы предлагаю ознакомиться с данным репозиторием для домашних работ</font>

# %% [markdown]
# ### Выполнение задания № 1 - вывод кода

# %%
print("Меня зовут Евгений, и я готов страдать на курсе!")
# Out:
# Меня зовут Евгений, и я готов страдать на курсе!

# %% [markdown]
# ## Часть 2. Выполнение работы с кодом

# %% [markdown]
# ### Краткая информация "обо мне" :
# - ФИО: Сидоров Евгений АЛександрович
# - учебная группа: МИСТ 25-2-2
# - Hard Skills (Game Dev.): C#, C++, C, Blender, Unity, Zbrush, UE5, Substance Painter

# %% [markdown]
# ### Найдите остаток от деления 77 на 2

# %%
print(f"Остаток от деления 77 на 2 равен {77 % 2}")
# Out:
# Остаток от деления 77 на 2 равен 1

# %% [markdown]
# ### Узнайте четное ли число 22

# %%
# Некоторая переменная для хранения числа
value = 22
print(f"Число {value}{" НЕ" * (value % 2)} является чётным")
# Out:
# Число 22 является чётным

# %% [markdown]
# ### Посчитайте 86 в степени 7

# %%
print(f"Результат возведения 86 в 7-ю степень равен {86 ** 7}")
# Out:
# Результат возведения 86 в 7-ю степень равен 34792782221696

# %% [markdown]
# ### Найдите квадратный корень из 3686400

# %%
print(f"Квадратный корень 3686400 равен {3686400 ** 0.5}")
# Out:
# Квадратный корень 3686400 равен 1920.0
